# %%
using Cassette;
using DifferentialEquations;

# %%
function main()
    
    # define our ode
    function sir_ode(du, u, p, t)  
        #Infected per-Capita Rate
        β = p[1]
        #Recover per-capita rate
        γ = p[2]
        #Susceptible Individuals
        S = u[1]
        #Infected by Infected Individuals
        I = u[2]

        du[1] = -β * S * I
        du[2] = β * S * I - γ * I
        du[3] = γ * I
    end

    #Pram = (Infected Per Capita Rate, Recover Per Capita Rate)
    pram = [0.1,0.05]
    #Initial Prams = (Susceptible Individuals, Infected by Infected Individuals)
    init = [0.99,0.01,0.0]
    tspan = (0.0,200.0)
    
    # create a var to our problem
    sir_prob = ODEProblem(sir_ode, init, tspan, pram)
    solution = solve(sir_prob)
    
end
# Out:
# main (generic function with 1 method)

# %%
""" 
trace_collector(func, args, ret, subtrace)

a structure to hold metadata for recursive type information
"""
mutable struct trace_collector
    func
    args
    ret
    subtrace::Vector{trace_collector}
end
# Out:
# trace_collector

# %%
"""    
trace_collect(func, args...)

creates a new trace_collector logging the input argument types and function name. You have to set the `ret` field after you call the function. 
This constructor creates the subtrace field for use in Cassette.similarcontext.
"""
function trace_collect(func, args...)
    return trace_collector(func, typeof.(args), nothing, trace_collector[])
end
# Out:
# trace_collect

# %%
# define the 
Cassette.@context typeCtx;

# %%
extractor = trace_collector[]
# Out:
# 0-element Array{trace_collector,1}

# %%
ctx = typeCtx(metadata = extractor)
# Out:
# Cassette.Context{nametype(typeCtx),Array{trace_collector,1},Nothing,getfield(Cassette, Symbol("##PassType#363")),Nothing,Nothing}(nametype(typeCtx)(), trace_collector[], nothing, getfield(Cassette, Symbol("##PassType#363"))(), nothing, nothing)

# %%
# add boilerplate for functionality
function Cassette.overdub(ctx::typeCtx, args...)
    c = trace_collect(args...)
    push!(ctx.metadata, c)
    if Cassette.canrecurse(ctx, args...)
        newctx = Cassette.similarcontext(ctx, metadata = c.subtrace)
        z = Cassette.recurse(newctx, args...)
        c.ret = typeof(z)
        return z
    else
        z = Cassette.fallback(ctx, args...)
        c.ret = typeof(z)
        return z
    end
end

# %%
function Cassette.canrecurse(ctx::typeCtx,::typeof(ODEProblem),args...)
    return false
end

function Cassette.canrecurse(ctx::typeCtx,::typeof(Base.vect),args...)
    return false
end

# %%
Cassette.overdub(ctx,main)
# Out:
# retcode: Success
# Interpolation: 3rd order Hermite
# t: 16-element Array{Float64,1}:
#    0.0
#    0.12810751461600167
#    1.4091826607760183
#    5.1680782805989995
#   10.994513112907462
#   18.301871797637222
#   27.798934064171767
#   39.529419388483916
#   54.032659926311176
#   71.0333307422792
#   90.35176885029713
#  110.76614128323645
#  137.20279004817846
#  160.26481040857357
#  195.13090370189352
#  200.0
# u: 16-element Array{Array{Float64,1},1}:
#  [0.99, 0.01, 0.0]
#  [0.989873, 0.010063, 6.42552e-5]
#  [0.988557, 0.0107138, 0.000729462]
#  [0.984197, 0.0128634, 0.00293922]
#  [0.975719, 0.0170157, 0.00726505]
#  [0.961344, 0.0239699, 0.0146865]
#  [0.934383, 0.0367076, 0.0289091]
#  [0.883849, 0.0594416, 0.0567092]
#  [0.789657, 0.0972901, 0.113053]
#  [0.643584, 0.14109, 0.215326]
#  [0.478491, 0.15798, 0.363529]
#  [0.354016, 0.131801, 0.514183]
#  [0.26819, 0.0788203, 0.652989]
#  [0.233414, 0.0441549, 0.722431]
#  [0.211434, 0.0166631, 0.771903]
#  [0.20984, 0.0144731, 0.775687]

# %%
extractor
# Out:
# 1-element Array{trace_collector,1}:
#  trace_collector(main, (), OrdinaryDiffEq.ODECompositeSolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},CompositeAlgorithm{Tuple{Tsit5,Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType}},AutoSwitch{Tsit5,Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType},Rational{Int64},Float64}},OrdinaryDiffEq.CompositeInterpolationData{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},OrdinaryDiffEq.Rosenbrock23Cache{Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rosenbrock23ConstantCache{Float64,typeof(identity),typeof(identity)},DiffEqDiffTools.TimeGradientWrapper{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Array{Float64,1}},DiffEqDiffTools.UJacobianWrapper{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Float64,Array{Float64,1}},LinSolveFactorize{typeof(LinearAlgebra.lu!)},DiffEqDiffTools.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Val{:central},Float64,Val{true}},DiffEqDiffTools.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Val{:central},Float64,Val{true}}}},AutoSwitch{Tsit5,Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType},Rational{Int64},Float64}}}}, trace_collector[trace_collector(vect, (Float64, Float64), Array{Float64,1}, trace_collector[]), trace_collector(vect, (Float64, Float64, Float64), Array{Float64,1}, trace_collector[]), trace_collector(tuple, (Float64, Float64), Tuple{Float64,Float64}, trace_collector[]), trace_collector(ODEProblem, (#sir_ode#3, Array{Float64,1}, Tuple{Float64,Float64}, Array{Float64,1}), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,#sir_ode#3,UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,StandardODEProblem}, trace_collector[]), trace_collector(solve, (ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,#sir_ode#3,UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,StandardODEProblem},), ODECompositeSolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,#sir_ode#3,UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,StandardODEProblem},CompositeAlgorithm{Tuple{Tsit5,Rosenbrock23{0,false,LinSolveFactorize{typeof(lu!)},DataType}},AutoSwitch{Tsit5,Rosenbrock23{0,false,LinSolveFactorize{typeof(lu!)},DataType},Rational{Int64},Float64}},CompositeInterpolationData{ODEFunction{true,#sir_ode#3,UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},CompositeCache{Tuple{Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Tsit5ConstantCache{Float64,Float64}},Rosenbrock23Cache{Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},Rosenbrock23ConstantCache{Float64,typeof(identity),typeof(identity)},TimeG ...
# true*I, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing), (Array{Float64,1}, Array{Float64,1}, Array{Float64,1}, Float64), Float64, trace_collector[trace_collector(#sir_ode#3(), (Array{Float64,1}, Array{Float64,1}, Array{Float64,1}, Float64), Float64, trace_collector[trace_collector(getindex, (Array{Float64,1}, Int64), Float64, trace_collector[trace_collector(arrayref, (Bool, Array{Float64,1}, Int64), Float64, trace_collector[])]), trace_collector(getindex, (Array{Float64,1}, Int64), Float64, trace_collector[trace_collector(arrayref, (Bool, Array{Float64,1}, Int64), Float64, trace_collector[])]), trace_collector(getindex, (Array{Float64,1}, Int64), Float64, trace_collector[trace_collector(arrayref, (Bool, Array{Float64,1}, Int64), Float64, trace_collector[])]), trace_collector(getindex, (Array{Float64,1}, Int64), Float64, trace_collector[trace_collector(arrayref, (Bool, Array{Float64,1}, Int64), Float64, trace_collector[])]), trace_collector(-, (Float64,), Float64, trace_collector[trace_collector(neg_float, (Float64,), Float64, trace_collector[])]), trace_collector(*, (Float64, Float64, Float64), Float64, trace_collector[trace_collector(*, (Float64, Float64), Float64, trace_collector[trace_collector(mul_float, (Float64, Float64), Float64, trace_collector[])]), trace_collector(*, (Float64, Float64), Float64, trace_collector[trace_collector(mul_float, (Float64, Float64), Float64, trace_collector[])]), trace_collector(tuple, (typeof(*), Float64), Tuple{typeof(*),Float64}, trace_collector[]), trace_collector(afoldl, (typeof(*), Float64), Float64, trace_collector[])]), trace_collector(setindex!, (Array{Float64,1}, Float64, Int64), Array{Float64,1}, trace_collector[trace_collector(convert, (DataType, Float64), Float64, trace_collector[]), trace_collector(typeassert, (Float64, DataType), Float64, trace_collector[]), trace_collector(arrayset, (Bool, Array{Float64,1}, Float64, Int64), Array{Float64,1}, trace_collector[])]), trace_collector(*, (Float64, Float64, Float64), Float64, trace_collector[trace_collector(*, (Float64, Float64), Float64, trace_collector[trace_collector(mul_float, (Float64, Float64), Float64, trace_collector[])]), trace_collector(*, (Float64, Float64), Float64, trace_collector[trace_collector(mul_float, (Float64, Float64), Float64, trace_collector[])]), trace_collector(tuple, (typeof(*), Float64), Tuple{typeof(*),Float64}, trace_collector[]), trace_collector(afoldl, (typeof(*), Float64), Float64, trace_collector[])]), trace_collector(*, (Float64, Float64), Float64, trace_collector[trace_collector(mul_float, (Float64, Float64), Float64, trace_collector[])]), trace_collector(-, (Float64, Float64), Float64, trace_collector[trace_collector(sub_float, (Float64, Float64), Float64, trace_collector[])]), trace_collector(setindex!, (Array{Float64,1}, Float64, Int64), Array{Float64,1}, trace_collector[trace_collector(convert, (DataType, Float64), Float64, trace_collector[]), trace_collector(typeassert, (Float64, DataType), Float64, trace_collector[]), trace_collector(arrayset, (Bool, Array{Float64,1}, Float64, Int64), Array{Float64,1}, trace_collector[])]), trace_collector(*, (Float64, Float64), Float64, trace_collector[trace_collector(mul_float, (Float64, Float64), Float64, trace_collector[])]), trace_collector(setindex!, (Array{Float64,1}, Float64, Int64), Array{Float64,1}, trace_collector[trace_collector(convert, (DataType, Float64), Float64, trace_collector[]), trace_collector(typeassert, (Float64, DataType), Float64, trace_collector[]), trace_collector(arrayset, (Bool, Array{Float64,1}, Float64, Int64), Array{Float64,1}, trace_collector[])])])])]), trace_collector(resize!, (Array{Array{Float64,1},1}, Int64), Array{Array{Float64,1},1}, trace_collector[trace_collector(length, (Array{Array{Float64,1},1},), Int64, trace_collector[trace_collector(arraylen, (Array{Array{Float64,1},1},), Int64, trace_collector[])]), trace_collector(>, (Int64, Int64), Bool, trace_collector[trace_collector(<, (Int64, Int64 ...

# %%
for frame in extractor
    println(frame.func, frame.args)
end
# Out:
# main()

# %%
function foo(collector::trace_collector)
    println(collector.func, collector.args)
    for frame in collector.subtrace
         foo(frame)
    end
end
# Out:
# foo (generic function with 1 method)

# %%
foo(extractor[1])
# Out:
# main()
# Base.vect(Float64, Float64)
# Base.vect(Float64, Float64, Float64)
# tuple(Float64, Float64)
# ODEProblem(getfield(Main, Symbol("#sir_ode#3")), Array{Float64,1}, Tuple{Float64,Float64}, Array{Float64,1})
# DiffEqBase.solve(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},)
# NamedTuple()
# pairs(NamedTuple{(),Tuple{}},)
# keys(NamedTuple{(),Tuple{}},)
# Base.Iterators.Pairs(NamedTuple{(),Tuple{}}, Tuple{})
# tuple(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, typeof(solve), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem})
# DiffEqBase.#solve#425(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, typeof(solve), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem})
# DiffEqBase.get_concrete_problem(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem}, Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}})
# typeof(Tuple{Float64,Float64},)
# <:(DataType, DataType)
# tuple(Nothing, Nothing)
# ==(Tuple{Float64,Float64}, Tuple{Nothing,Nothing})
# length(Tuple{Float64,Float64},)
# nfields(Tuple{Float64,Float64},)
# length(Tuple{Nothing,Nothing},)
# nfields(Tuple{Nothing,Nothing},)
# ==(Int64, Int64)
# ===(Int64, Int64)
# Base._eq(Tuple{Float64,Float64}, Tuple{Nothing,Nothing})
# getindex(Tuple{Float64,Float64}, Int64)
# getfield(Tuple{Float64,Float64}, Int64, Bool)
# getindex(Tuple{Nothing,Nothing}, Int64)
# getfield(Tuple{Nothing,Nothing}, Int64, Bool)
# ==(Float64, Nothing)
# ===(Float64, Nothing)
# ===(Bool, Bool)
# typeof(Array{Float64,1},)
# <:(DataType, DataType)
# DiffEqBase.handle_distribution_u0(Array{Float64,1},)
# Core.apply_type(UnionAll, Tuple{Symbol,Symbol})
# tuple(Array{Float64,1}, Tuple{Float64,Float64})
# NamedTuple{(:u0, :tspan),T} where T<:Tuple(Tuple{Array{Float64,1},Tuple{Float64,Float64}},)
# Core.kwfunc(typeof(remake),)
# getfield(DiffEqBase, Symbol("#kw##remake"))()(NamedTuple{(:u0, :tspan),Tuple{Array{Float64,1},Tuple{Float64,Float64}}}, typeof(remake), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem})
# DiffEqBase.remaker_of(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},)
# DiffEqBase.parameterless_type(DataType,)
# Base.typename(DataType,)
# DiffEqBase.isinplace(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},)
# Core.apply_type(UnionAll, Bool)
# NamedTuple()
# DiffEqBase.struct_as_namedtuple(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},)
# Core.apply_type(UnionAll, NTuple{6,Symbol})
# tuple(ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}, Array{Float64,1}, Tuple{Float64,Float64}, Array{Float64,1}, Nothing, DiffEqBase.StandardODEProblem)
# NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),T} where T<:Tuple(Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem},)
# merge(NamedTuple{(),Tuple{}}, NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}})
# merge(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Base.Iterators.Pairs{Symbol,Any,Tuple{Symbol,Symbol},NamedTuple{(:u0, :tspan),Tuple{Array{Float64,1},Tuple{Float64,Float64}}}})
# merge(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, NamedTuple{(:u0, :tspan),Tuple{Array{Float64,1},Tuple{Float64,Float64}}})
# Core.apply_type(UnionAll, NTuple{6,Symbol}, DataType)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:u0, :tspan),Tuple{Array{Float64,1},Tuple{Float64,Float64}}}, Symbol)
# getfield(NamedTuple{(:u0, :tspan),Tuple{Array{Float64,1},Tuple{Float64,Float64}}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# tuple(ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}, Array{Float64,1}, Tuple{Float64,Float64}, Array{Float64,1}, Nothing, DiffEqBase.StandardODEProblem)
# NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}(Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem},)
# Core.apply_type(UnionAll, NTuple{6,Symbol}, DataType)
# getfield(Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}, Int64)
# getfield(Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}, Int64)
# getfield(Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}, Int64)
# getfield(Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}, Int64)
# getfield(Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}, Int64)
# getfield(Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}, Int64)
# isempty(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}},)
# Core.kwfunc(UnionAll,)
# getfield(Core, Symbol("#kw#Type"))()(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, UnionAll)
# haskey(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# isdefined(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getindex(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# Core.apply_type(UnionAll, Bool)
# typeassert(ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}, DataType)
# haskey(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# isdefined(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getindex(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# haskey(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# isdefined(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getindex(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# haskey(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# isdefined(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getindex(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# haskey(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# isdefined(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getindex(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# haskey(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# isdefined(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getindex(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# getfield(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, Symbol)
# Core.apply_type(UnionAll, NTuple{6,Symbol})
# Base.structdiff(NamedTuple{(:f, :u0, :tspan, :p, :callback, :problem_type),Tuple{ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Float64,1},Tuple{Float64,Float64},Array{Float64,1},Nothing,DiffEqBase.StandardODEProblem}}, UnionAll)
# Core.apply_type(UnionAll, Tuple{}, DataType)
# NamedTuple{(),Tuple{}}(Tuple{},)
# Core.apply_type(UnionAll, Tuple{}, DataType)
# pairs(NamedTuple{(),Tuple{}},)
# keys(NamedTuple{(),Tuple{}},)
# Base.Iterators.Pairs(NamedTuple{(),Tuple{}}, Tuple{})
# isempty(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},)
# Base.isdone(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},)
# tuple(Tuple{},)
# Base.isdone(Tuple{},)
# !==(Missing, Missing)
# ===(Missing, Missing)
# !(Bool,)
# not_int(Bool,)
# iterate(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},)
# tuple(Tuple{},)
# iterate(Tuple{},)
# iterate(Tuple{}, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# length(Tuple{},)
# nfields(Tuple{},)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# ===(Nothing, Nothing)
# ===(Nothing, Nothing)
# getfield(DiffEqBase, Symbol("##call#296#299"))()(ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}, Array{Float64,1}, Tuple{Float64,Float64}, Array{Float64,1}, DiffEqBase.StandardODEProblem, Nothing, UnionAll)
# DiffEqBase.promote_tspan(Tuple{Float64,Float64},)
# typeof(Array{Float64,1},)
# typeof(Tuple{Float64,Float64},)
# DiffEqBase.isinplace(ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},)
# typeof(Array{Float64,1},)
# typeof(ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},)
# typeof(Nothing,)
# typeof(DiffEqBase.StandardODEProblem,)
# Core.apply_type(UnionAll, DataType, DataType, Bool, DataType, DataType, DataType, DataType)
# fieldtype(DataType, Symbol)
# convert(DataType, ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing})
# fieldtype(DataType, Symbol)
# convert(DataType, Array{Float64,1})
# isa(Array{Float64,1}, DataType)
# fieldtype(DataType, Symbol)
# fieldtype(DataType, Symbol)
# convert(DataType, Array{Float64,1})
# isa(Array{Float64,1}, DataType)
# fieldtype(DataType, Symbol)
# convert(DataType, Nothing)
# fieldtype(DataType, Symbol)
# convert(DataType, DiffEqBase.StandardODEProblem)
# haskey(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, Symbol)
# in(Symbol, Tuple{})
# iterate(Tuple{},)
# iterate(Tuple{}, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# length(Tuple{},)
# nfields(Tuple{},)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# ===(Nothing, Nothing)
# not_int(Bool,)
# isempty(Tuple{},)
# !(Bool,)
# not_int(Bool,)
# NamedTuple()
# merge(NamedTuple{(),Tuple{}}, Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}})
# merge(NamedTuple{(),Tuple{}}, NamedTuple{(),Tuple{}})
# isempty(NamedTuple{(),Tuple{}},)
# tuple(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},)
# DiffEqBase.__solve(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},)
# NamedTuple()
# pairs(NamedTuple{(),Tuple{}},)
# keys(NamedTuple{(),Tuple{}},)
# Base.Iterators.Pairs(NamedTuple{(),Tuple{}}, Tuple{})
# tuple(Bool, Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, typeof(DiffEqBase.__solve), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem})
# DifferentialEquations.#__solve#1(Bool, Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, typeof(DiffEqBase.__solve), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem})
# length(Tuple{},)
# nfields(Tuple{},)
# >(Int64, Int64)
# <(Int64, Int64)
# slt_int(Int64, Int64)
# typeassert(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem}, DataType)
# Core.apply_type(UnionAll, Tuple{Symbol})
# tuple(Bool,)
# NamedTuple{(:default_set,),T} where T<:Tuple(Tuple{Bool},)
# merge(NamedTuple{(:default_set,),Tuple{Bool}}, Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}})
# merge(NamedTuple{(:default_set,),Tuple{Bool}}, NamedTuple{(),Tuple{}})
# Core.apply_type(UnionAll, Tuple{Symbol}, DataType)
# getfield(NamedTuple{(:default_set,),Tuple{Bool}}, Symbol)
# tuple(Bool,)
# NamedTuple{(:default_set,),Tuple{Bool}}(Tuple{Bool},)
# Core.apply_type(UnionAll, Tuple{Symbol}, DataType)
# getfield(Tuple{Bool}, Int64)
# Core.kwfunc(typeof(DiffEqBase.__solve),)
# tuple(NamedTuple{(:default_set,),Tuple{Bool}}, typeof(DiffEqBase.__solve), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem}, Nothing)
# getfield(DiffEqBase, Symbol("#kw##__solve"))()(NamedTuple{(:default_set,),Tuple{Bool}}, typeof(DiffEqBase.__solve), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem}, Nothing)
# ==(Bool, Bool)
# ===(Bool, Bool)
# NamedTuple()
# merge(NamedTuple{(),Tuple{}}, Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}})
# merge(NamedTuple{(),Tuple{}}, NamedTuple{(),Tuple{}})
# isempty(NamedTuple{(),Tuple{}},)
# DifferentialEquations.default_algorithm(ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem},)
# NamedTuple()
# pairs(NamedTuple{(),Tuple{}},)
# keys(NamedTuple{(),Tuple{}},)
# Base.Iterators.Pairs(NamedTuple{(),Tuple{}}, Tuple{})
# DifferentialEquations.#default_algorithm#4(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, typeof(default_algorithm), ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,getfield(Main, Symbol("#sir_ode#3")),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Nothing,DiffEqBase.StandardODEProblem})
# Core.apply_type(UnionAll, DataType, DataType)
# Dict{Symbol,Any}(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},)
# Core.apply_type(UnionAll, DataType, DataType)
# Dict{Symbol,Any}()
# Core.apply_type(UnionAll, DataType, DataType)
# Core.apply_type(UnionAll, DataType, Int64)
# zeros(DataType, Int64)
# zeros(DataType, Tuple{Int64})
# Core.apply_type(UnionAll, DataType, Int64)
# map(typeof(Base.to_dim), Tuple{Int64})
# getindex(Tuple{Int64}, Int64)
# getfield(Tuple{Int64}, Int64, Bool)
# Base.to_dim(Int64,)
# tuple(Int64,)
# Array{UInt8,1}(UndefInitializer, Tuple{Int64})
# Core.apply_type(UnionAll, DataType, Int64)
# getfield(Tuple{Int64}, Int64)
# Array{UInt8,1}(UndefInitializer, Int64)
# Core.cconvert(DataType, Int64)
# Core.convert(DataType, Int64)
# Core.apply_type(UnionAll, DataType, Int64)
# Core.unsafe_convert(DataType, Int64)
# zero(DataType,)
# convert(DataType, Int64)
# UInt8(Int64,)
# Core.toUInt8(Int64,)
# Core.checked_trunc_uint(DataType, Int64)
# trunc_int(DataType, Int64)
# zext_int(DataType, UInt8)
# eq_int(Int64, Int64)
# typeassert(UInt8, DataType)
# fill!(Array{UInt8,1}, UInt8)
# Core.apply_type(UnionAll, DataType)
# Base.cconvert(DataType, Array{UInt8,1})
# Base.cconvert(DataType, UInt8)
# convert(DataType, UInt8)
# Int32(UInt8,)
# Core.toInt32(UInt8,)
# zext_int(DataType, UInt8)
# typeassert(Int32, DataType)
# length(Array{UInt8,1},)
# arraylen(Array{UInt8,1},)
# Base.cconvert(DataType, Int64)
# convert(DataType, Int64)
# UInt64(Int64,)
# Core.toUInt64(Int64,)
# Core.check_top_bit(Int64,)
# Core.is_top_bit_set(Int64,)
# Core.sizeof(Int64,)
# shl_int(Int64, Int64)
# sub_int(Int64, Int64)
# lshr_int(Int64, Int64)
# trunc_int(DataType, Int64)
# trunc_int(DataType, Int64)
# eq_int(UInt8, UInt8)
# bitcast(DataType, Int64)
# typeassert(UInt64, DataType)
# Core.apply_type(UnionAll, DataType)
# Base.unsafe_convert(DataType, Array{UInt8,1})
# Core.apply_type(UnionAll, DataType)
# Core.apply_type(UnionAll, DataType)
# Base.unsafe_convert(DataType, Array{UInt8,1})
# convert(DataType, Ptr{UInt8})
# Core.apply_type(UnionAll, DataType)
# bitcast(DataType, Ptr{UInt8})
# Base.unsafe_convert(DataType, Int32)
# Base.unsafe_convert(DataType, UInt64)
# convert(DataType, Array{UInt8,1})
# isa(Array{UInt8,1}, DataType)
# Core.apply_type(UnionAll, DataType, Int64)
# Core.apply_type(UnionAll, DataType)
# Array{Symbol,1}(UndefInitializer, Int64)
# Core.cconvert(DataType, Int64)
# Core.convert(DataType, Int64)
# Core.apply_type(UnionAll, DataType, Int64)
# Core.unsafe_convert(DataType, Int64)
# convert(DataType, Array{Symbol,1})
# isa(Array{Symbol,1}, DataType)
# Core.apply_type(UnionAll, DataType, Int64)
# Core.apply_type(UnionAll, DataType)
# Array{Any,1}(UndefInitializer, Int64)
# Core.cconvert(DataType, Int64)
# Core.convert(DataType, Int64)
# Core.apply_type(UnionAll, DataType, Int64)
# Core.unsafe_convert(DataType, Int64)
# convert(DataType, Array{Any,1})
# isa(Array{Any,1}, DataType)
# convert(DataType, Int64)
# convert(DataType, Int64)
# convert(DataType, Int64)
# UInt64(Int64,)
# Core.toUInt64(Int64,)
# Core.check_top_bit(Int64,)
# Core.is_top_bit_set(Int64,)
# Core.sizeof(Int64,)
# shl_int(Int64, Int64)
# sub_int(Int64, Int64)
# lshr_int(Int64, Int64)
# trunc_int(DataType, Int64)
# trunc_int(DataType, Int64)
# eq_int(UInt8, UInt8)
# bitcast(DataType, Int64)
# typeassert(UInt64, DataType)
# convert(DataType, Int64)
# convert(DataType, Int64)
# iterate(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},)
# tuple(Tuple{},)
# iterate(Tuple{},)
# iterate(Tuple{}, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# length(Tuple{},)
# nfields(Tuple{},)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# ===(Nothing, Nothing)
# ===(Nothing, Nothing)
# not_int(Bool,)
# getindex(DataType,)
# Core.apply_type(UnionAll, DataType)
# Array{Any,1}()
# Core.apply_type(UnionAll, DataType, Int64)
# Array{Any,1}(UndefInitializer, Int64)
# Core.cconvert(DataType, Int64)
# Core.convert(DataType, Int64)
# Core.apply_type(UnionAll, DataType, Int64)
# Core.unsafe_convert(DataType, Int64)
# Core.apply_type(UnionAll, Tuple{Symbol})
# tuple(Bool,)
# NamedTuple{(:autodiff,),T} where T<:Tuple(Tuple{Bool},)
# Core.kwfunc(UnionAll,)
# getfield(Core, Symbol("#kw#Type"))()(NamedTuple{(:autodiff,),Tuple{Bool}}, UnionAll)
# haskey(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# isdefined(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# haskey(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# isdefined(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# getindex(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# getfield(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# haskey(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# isdefined(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# Core.apply_type(UnionAll, Symbol)
# haskey(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# isdefined(NamedTuple{(:autodiff,),Tuple{Bool}}, Symbol)
# Core.apply_type(UnionAll, NTuple{4,Symbol})
# Base.structdiff(NamedTuple{(:autodiff,),Tuple{Bool}}, UnionAll)
# Core.apply_type(UnionAll, Tuple{}, DataType)
# NamedTuple{(),Tuple{}}(Tuple{},)
# Core.apply_type(UnionAll, Tuple{}, DataType)
# pairs(NamedTuple{(),Tuple{}},)
# keys(NamedTuple{(),Tuple{}},)
# Base.Iterators.Pairs(NamedTuple{(),Tuple{}}, Tuple{})
# isempty(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},)
# Base.isdone(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},)
# tuple(Tuple{},)
# Base.isdone(Tuple{},)
# !==(Missing, Missing)
# ===(Missing, Missing)
# !(Bool,)
# not_int(Bool,)
# iterate(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},)
# tuple(Tuple{},)
# iterate(Tuple{},)
# iterate(Tuple{}, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# length(Tuple{},)
# nfields(Tuple{},)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# ===(Nothing, Nothing)
# ===(Nothing, Nothing)
# OrdinaryDiffEq.#Rosenbrock23#51(Int64, Bool, DataType, LinSolveFactorize{typeof(LinearAlgebra.lu!)}, UnionAll)
# typeof(LinSolveFactorize{typeof(LinearAlgebra.lu!)},)
# typeof(DataType,)
# Core.apply_type(UnionAll, Int64, Bool, DataType, DataType)
# Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType}(LinSolveFactorize{typeof(LinearAlgebra.lu!)}, DataType)
# Core.apply_type(UnionAll, Int64, Bool, DataType, DataType)
# convert(DataType, LinSolveFactorize{typeof(LinearAlgebra.lu!)})
# convert(DataType, DataType)
# OrdinaryDiffEq.AutoTsit5(Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType},)
# NamedTuple()
# pairs(NamedTuple{(),Tuple{}},)
# keys(NamedTuple{(),Tuple{}},)
# Base.Iterators.Pairs(NamedTuple{(),Tuple{}}, Tuple{})
# OrdinaryDiffEq.#AutoTsit5#492(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, typeof(AutoTsit5), Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType})
# Tsit5()
# NamedTuple()
# merge(NamedTuple{(),Tuple{}}, Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}})
# merge(NamedTuple{(),Tuple{}}, NamedTuple{(),Tuple{}})
# isempty(NamedTuple{(),Tuple{}},)
# OrdinaryDiffEq.AutoAlgSwitch(Tsit5, Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType})
# NamedTuple()
# pairs(NamedTuple{(),Tuple{}},)
# keys(NamedTuple{(),Tuple{}},)
# Base.Iterators.Pairs(NamedTuple{(),Tuple{}}, Tuple{})
# OrdinaryDiffEq.#AutoAlgSwitch#491(Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, typeof(OrdinaryDiffEq.AutoAlgSwitch), Tsit5, Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType})
# NamedTuple()
# merge(NamedTuple{(),Tuple{}}, Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}})
# merge(NamedTuple{(),Tuple{}}, NamedTuple{(),Tuple{}})
# isempty(NamedTuple{(),Tuple{}},)
# AutoSwitch(Tsit5, Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType})
# tuple(Tsit5, Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType})
# CompositeAlgorithm(Tuple{Tsit5,Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType}}, AutoSwitch{Tsit5,Rosenbrock23{0,false,LinSolveFactorize{typeof(LinearAlgebra.lu!)},DataType},Rational{Int64},Float64})
# eltype(Array{Float64,1},)
# typeof(Array{Float64,1},)
# DifferentialEquations.get_alg_hints(Dict{Symbol,Any},)
# keys(Dict{Symbol,Any},)
# Base.KeySet(Dict{Symbol,Any},)
# in(Symbol, Base.KeySet{Symbol,Dict{Symbol,Any}})
# Base.ht_keyindex(Dict{Symbol,Any}, Symbol)
# length(Array{Symbol,1},)
# arraylen(Array{Symbol,1},)
# Base.hashindex(Symbol, Int64)
# hash(Symbol,)
# zero(DataType,)
# convert(DataType, Int64)
# UInt64(Int64,)
# Core.toUInt64(Int64,)
# Core.check_top_bit(Int64,)
# Core.is_top_bit_set(Int64,)
# Core.sizeof(Int64,)
# shl_int(Int64, Int64)
# sub_int(Int64, Int64)
# lshr_int(Int64, Int64)
# trunc_int(DataType, Int64)
# trunc_int(DataType, Int64)
# eq_int(UInt8, UInt8)
# bitcast(DataType, Int64)
# typeassert(UInt64, DataType)
# hash(Symbol, UInt64)
# *(Int64, UInt64)
# Base.promote_typeof(Int64, UInt64)
# typeof(Int64,)
# Base.promote_typeof(UInt64,)
# typeof(UInt64,)
# promote_type(DataType, DataType)
# promote_rule(DataType, DataType)
# promote_rule(DataType, DataType)
# Base.promote_result(DataType, DataType, Core.TypeofBottom, DataType)
# promote_type(Core.TypeofBottom, DataType)
# rem(Int64, DataType)
# bitcast(DataType, Int64)
# rem(UInt64, DataType)
# tuple(Int64, UInt64)
# tuple(UInt64, UInt64)
# Base.not_sametype(Tuple{Int64,UInt64}, Tuple{UInt64,UInt64})
# *(UInt64, UInt64)
# mul_int(UInt64, UInt64)
# objectid(Symbol,)
# -(UInt64, UInt64)
# sub_int(UInt64, UInt64)
# Base.hash_uint(UInt64,)
# Base.hash_64_64(UInt64,)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# ~(UInt64,)
# not_int(UInt64,)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# >>(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# xor(UInt64, UInt64)
# xor_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# +(UInt64, UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# tuple(typeof(+), UInt64)
# Base.afoldl(typeof(+), UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# >>(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# xor(UInt64, UInt64)
# xor_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# +(UInt64, UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# tuple(typeof(+), UInt64)
# Base.afoldl(typeof(+), UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# >>(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# xor(UInt64, UInt64)
# xor_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# rem(UInt64, DataType)
# bitcast(DataType, UInt64)
# -(Int64, Int64)
# sub_int(Int64, Int64)
# &(Int64, Int64)
# and_int(Int64, Int64)
# +(Int64, Int64)
# add_int(Int64, Int64)
# typeassert(Int64, DataType)
# Base.isslotempty(Dict{Symbol,Any}, Int64)
# getindex(Array{UInt8,1}, Int64)
# Core.arrayref(Bool, Array{UInt8,1}, Int64)
# ==(UInt8, UInt8)
# ===(UInt8, UInt8)
# >=(Int64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# getindex(DataType, Symbol)
# Core.apply_type(UnionAll, DataType)
# Array{Symbol,1}(UndefInitializer, Int64)
# Core.cconvert(DataType, Int64)
# Core.convert(DataType, Int64)
# Core.apply_type(UnionAll, DataType, Int64)
# Core.unsafe_convert(DataType, Int64)
# setindex!(Array{Symbol,1}, Symbol, Int64)
# convert(DataType, Symbol)
# typeassert(Symbol, DataType)
# Core.arrayset(Bool, Array{Symbol,1}, Symbol, Int64)
# DifferentialEquations.get_tolerance_level(Dict{Symbol,Any},)
# keys(Dict{Symbol,Any},)
# Base.KeySet(Dict{Symbol,Any},)
# in(Symbol, Base.KeySet{Symbol,Dict{Symbol,Any}})
# Base.ht_keyindex(Dict{Symbol,Any}, Symbol)
# length(Array{Symbol,1},)
# arraylen(Array{Symbol,1},)
# Base.hashindex(Symbol, Int64)
# hash(Symbol,)
# zero(DataType,)
# convert(DataType, Int64)
# UInt64(Int64,)
# Core.toUInt64(Int64,)
# Core.check_top_bit(Int64,)
# Core.is_top_bit_set(Int64,)
# Core.sizeof(Int64,)
# shl_int(Int64, Int64)
# sub_int(Int64, Int64)
# lshr_int(Int64, Int64)
# trunc_int(DataType, Int64)
# trunc_int(DataType, Int64)
# eq_int(UInt8, UInt8)
# bitcast(DataType, Int64)
# typeassert(UInt64, DataType)
# hash(Symbol, UInt64)
# *(Int64, UInt64)
# Base.promote_typeof(Int64, UInt64)
# typeof(Int64,)
# Base.promote_typeof(UInt64,)
# typeof(UInt64,)
# promote_type(DataType, DataType)
# promote_rule(DataType, DataType)
# promote_rule(DataType, DataType)
# Base.promote_result(DataType, DataType, Core.TypeofBottom, DataType)
# promote_type(Core.TypeofBottom, DataType)
# rem(Int64, DataType)
# bitcast(DataType, Int64)
# rem(UInt64, DataType)
# tuple(Int64, UInt64)
# tuple(UInt64, UInt64)
# Base.not_sametype(Tuple{Int64,UInt64}, Tuple{UInt64,UInt64})
# *(UInt64, UInt64)
# mul_int(UInt64, UInt64)
# objectid(Symbol,)
# -(UInt64, UInt64)
# sub_int(UInt64, UInt64)
# Base.hash_uint(UInt64,)
# Base.hash_64_64(UInt64,)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# ~(UInt64,)
# not_int(UInt64,)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# >>(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# xor(UInt64, UInt64)
# xor_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# +(UInt64, UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# tuple(typeof(+), UInt64)
# Base.afoldl(typeof(+), UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# >>(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# xor(UInt64, UInt64)
# xor_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# +(UInt64, UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# tuple(typeof(+), UInt64)
# Base.afoldl(typeof(+), UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# >>(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# xor(UInt64, UInt64)
# xor_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# lshr_int(UInt64, UInt64)
# ifelse(Bool, UInt64, UInt64)
# +(UInt64, UInt64)
# add_int(UInt64, UInt64)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# rem(UInt64, DataType)
# bitcast(DataType, UInt64)
# -(Int64, Int64)
# sub_int(Int64, Int64)
# &(Int64, Int64)
# and_int(Int64, Int64)
# +(Int64, Int64)
# add_int(Int64, Int64)
# typeassert(Int64, DataType)
# Base.isslotempty(Dict{Symbol,Any}, Int64)
# getindex(Array{UInt8,1}, Int64)
# Core.arrayref(Bool, Array{UInt8,1}, Int64)
# ==(UInt8, UInt8)
# ===(UInt8, UInt8)
# >=(Int64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# >(Float64, Float64)
# <(Float64, Float64)
# lt_float(Float64, Float64)
# >(Float64, Float64)
# <(Float64, Float64)
# lt_float(Float64, Float64)
# DifferentialEquations.callbacks_exists(Dict{Symbol,Any},)
# keys(Dict{Symbol,Any},)
# Base.KeySet(Dict{Symbol,Any},)
# in(Symbol, Base.KeySet{Symbol,Dict{Symbol,Any}})
# Base.ht_keyindex(Dict{Symbol,Any}, Symbol)
# length(Array{Symbol,1},)
# arraylen(Array{Symbol,1},)
# Base.hashindex(Symbol, Int64)
# hash(Symbol,)
# zero(DataType,)
# convert(DataType, Int64)
# UInt64(Int64,)
# Core.toUInt64(Int64,)
# Core.check_top_bit(Int64,)
# Core.is_top_bit_set(Int64,)
# Core.sizeof(Int64,)
# shl_int(Int64, Int64)
# sub_int(Int64, Int64)
# lshr_int(Int64, Int64)
# trunc_int(DataType, Int64)
# trunc_int(DataType, Int64)
# eq_int(UInt8, UInt8)
# bitcast(DataType, Int64)
# typeassert(UInt64, DataType)
# hash(Symbol, UInt64)
# *(Int64, UInt64)
# Base.promote_typeof(Int64, UInt64)
# typeof(Int64,)
# Base.promote_typeof(UInt64,)
# typeof(UInt64,)
# promote_type(DataType, DataType)
# promote_rule(DataType, DataType)
# promote_rule(DataType, DataType)
# Base.promote_result(DataType, DataType, Core.TypeofBottom, DataType)
# promote_type(Core.TypeofBottom, DataType)
# rem(Int64, DataType)
# bitcast(DataType, Int64)
# rem(UInt64, DataType)
# tuple(Int64, UInt64)
# tuple(UInt64, UInt64)
# Base.not_sametype(Tuple{Int64,UInt64}, Tuple{UInt64,UInt64})
# *(UInt64, UInt64)
# mul_int(UInt64, UInt64)
# objectid(Symbol,)
# -(UInt64, UInt64)
# sub_int(UInt64, UInt64)
# Base.hash_uint(UInt64,)
# Base.hash_64_64(UInt64,)
# convert(DataType, UInt64)
# typeassert(UInt64, DataType)
# ~(UInt64,)
# not_int(UInt64,)
# <<(UInt64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# <<(UInt64, UInt64)
# shl_int(UInt64, UInt64)
# -(Int64,)
# neg_int(Int64,)
# unsigned(Int64,)
# reinterpret(DataType, Int64)
# bitcast(DataType, Int64)
# >>(UInt64, UInt64)
# ...
# oneunit(DataType,)
# one(DataType,)
# convert(DataType, Int64)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# ==(Int64, Int64)
# ===(Int64, Int64)
# step(Base.OneTo{Int64},)
# oneunit(DataType,)
# one(DataType,)
# convert(DataType, Int64)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# zero(DataType,)
# convert(DataType, Int64)
# -(Int64, Int64)
# sub_int(Int64, Int64)
# step(Base.OneTo{Int64},)
# oneunit(DataType,)
# one(DataType,)
# convert(DataType, Int64)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# zero(DataType,)
# convert(DataType, Int64)
# -(Int64, Int64)
# sub_int(Int64, Int64)
# ==(Int64, Int64)
# ===(Int64, Int64)
# &(Bool, Bool)
# and_int(Bool, Bool)
# last(Base.OneTo{Int64},)
# convert(DataType, Int64)
# last(Base.OneTo{Int64},)
# convert(DataType, Int64)
# ==(Int64, Int64)
# ===(Int64, Int64)
# &(Bool, Bool)
# and_int(Bool, Bool)
# ===(Bool, Bool)
# ismissing(Bool,)
# Base.tail(Tuple{Base.OneTo{Int64}},)
# Base.argtail(Base.OneTo{Int64},)
# Base.tail(Tuple{Base.OneTo{Int64}},)
# Base.argtail(Base.OneTo{Int64},)
# Base._eq(Tuple{}, Tuple{})
# ===(typeof(*), typeof(identity))
# Base.Broadcast.preprocess(Array{Float64,1}, Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Array{Float64,1},Array{Float64,1}}},Float64}})
# Core.apply_type(UnionAll, DataType)
# Base.Broadcast.preprocess_args(Array{Float64,1}, Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Array{Float64,1},Array{Float64,1}}},Float64})
# getindex(Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Array{Float64,1},Array{Float64,1}}},Float64}, Int64)
# getfield(Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Array{Float64,1},Array{Float64,1}}},Float64}, Int64, Bool)
# Base.Broadcast.preprocess(Array{Float64,1}, Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Array{Float64,1},Array{Float64,1}}})
# Core.apply_type(UnionAll, DataType)
# Base.Broadcast.preprocess_args(Array{Float64,1}, Tuple{Array{Float64,1},Array{Float64,1}})
# getindex(Tuple{Array{Float64,1},Array{Float64,1}}, Int64)
# getfield(Tuple{Array{Float64,1},Array{Float64,1}}, Int64, Bool)
# Base.Broadcast.preprocess(Array{Float64,1}, Array{Float64,1})
# Base.Broadcast.broadcast_unalias(Array{Float64,1}, Array{Float64,1})
# ===(Array{Float64,1}, Array{Float64,1})
# Base.unalias(Array{Float64,1}, Array{Float64,1})
# Base.mightalias(Array{Float64,1}, Array{Float64,1})
# Base.dataids(Array{Float64,1},)
# pointer(Array{Float64,1},)
# Core.apply_type(UnionAll, DataType)
# Base.unsafe_convert(DataType, Array{Float64,1})
# UInt64(Ptr{Float64},)
# bitcast(DataType, Ptr{Float64})
# tuple(UInt64,)
# Base.dataids(Array{Float64,1},)
# pointer(Array{Float64,1},)
# Core.apply_type(UnionAll, DataType)
# Base.unsafe_convert(DataType, Array{Float64,1})
# UInt64(Ptr{Float64},)
# bitcast(DataType, Ptr{Float64})
# tuple(UInt64,)
# Base._isdisjoint(Tuple{UInt64}, Tuple{UInt64})
# getindex(Tuple{UInt64}, Int64)
# getfield(Tuple{UInt64}, Int64, Bool)
# getindex(Tuple{UInt64}, Int64)
# getfield(Tuple{UInt64}, Int64, Bool)
# !=(UInt64, UInt64)
# ==(UInt64, UInt64)
# ===(UInt64, UInt64)
# !(Bool,)
# not_int(Bool,)
# !(Bool,)
# not_int(Bool,)
# Base.Broadcast.extrude(Array{Float64,1},)
# tuple(Array{Float64,1},)
# Base.Broadcast.newindexer(Array{Float64,1},)
# Base.Broadcast.broadcast_axes(Array{Float64,1},)
# axes(Array{Float64,1},)
# size(Array{Float64,1},)
# Core.arraysize(Array{Float64,1}, Int64)
# tuple(Int64,)
# map(UnionAll, Tuple{Int64})
# getindex(Tuple{Int64}, Int64)
# getfield(Tuple{Int64}, Int64, Bool)
# Base.OneTo(Int64,)
# tuple(Base.OneTo{Int64},)
# Base.Broadcast.shapeindexer(Tuple{Base.OneTo{Int64}},)
# Base.Broadcast._newindexer(Tuple{Base.OneTo{Int64}},)
# getindex(Tuple{Base.OneTo{Int64}}, Int64)
# getfield(Tuple{Base.OneTo{Int64}}, Int64, Bool)
# Base.tail(Tuple{Base.OneTo{Int64}},)
# Base.argtail(Base.OneTo{Int64},)
# Base.Broadcast._newindexer(Tuple{},)
# tuple(Tuple{}, Tuple{})
# Base.indexed_iterate(Tuple{Tuple{},Tuple{}}, Int64)
# Base.indexed_iterate(Tuple{Tuple{},Tuple{}}, Int64, Int64)
# getfield(Tuple{Tuple{},Tuple{}}, Int64)
# +(Int64, Int64)
# add_int(Int64, Int64)
# tuple(Tuple{}, Int64)
# getfield(Tuple{Tuple{},Int64}, Int64)
# getfield(Tuple{Tuple{},Int64}, Int64)
# Base.indexed_iterate(Tuple{Tuple{},Tuple{}}, Int64, Int64)
# getfield(Tuple{Tuple{},Tuple{}}, Int64)
# +(Int64, Int64)
# add_int(Int64, Int64)
# tuple(Tuple{}, Int64)
# getfield(Tuple{Tuple{},Int64}, Int64)
# length(Base.OneTo{Int64},)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# !=(Int64, Int64)
# ==(Int64, Int64)
# ===(Int64, Int64)
# !(Bool,)
# not_int(Bool,)
# tuple(Bool,)
# tuple(Bool,)
# first(Base.OneTo{Int64},)
# oneunit(DataType,)
# one(DataType,)
# convert(DataType, Int64)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# tuple(Int64,)
# tuple(Int64,)
# tuple(Tuple{Bool}, Tuple{Int64})
# Base.Broadcast.Extruded(Array{Float64,1}, Tuple{Bool}, Tuple{Int64})
# tuple(Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},)
# Base.tail(Tuple{Array{Float64,1},Array{Float64,1}},)
# Base.argtail(Array{Float64,1}, Array{Float64,1})
# Base.Broadcast.preprocess_args(Array{Float64,1}, Tuple{Array{Float64,1}})
# getindex(Tuple{Array{Float64,1}}, Int64)
# getfield(Tuple{Array{Float64,1}}, Int64, Bool)
# Base.Broadcast.preprocess(Array{Float64,1}, Array{Float64,1})
# Base.Broadcast.broadcast_unalias(Array{Float64,1}, Array{Float64,1})
# ===(Array{Float64,1}, Array{Float64,1})
# Base.unalias(Array{Float64,1}, Array{Float64,1})
# Base.mightalias(Array{Float64,1}, Array{Float64,1})
# Base.dataids(Array{Float64,1},)
# pointer(Array{Float64,1},)
# Core.apply_type(UnionAll, DataType)
# Base.unsafe_convert(DataType, Array{Float64,1})
# UInt64(Ptr{Float64},)
# bitcast(DataType, Ptr{Float64})
# tuple(UInt64,)
# Base.dataids(Array{Float64,1},)
# pointer(Array{Float64,1},)
# Core.apply_type(UnionAll, DataType)
# Base.unsafe_convert(DataType, Array{Float64,1})
# UInt64(Ptr{Float64},)
# bitcast(DataType, Ptr{Float64})
# tuple(UInt64,)
# Base._isdisjoint(Tuple{UInt64}, Tuple{UInt64})
# getindex(Tuple{UInt64}, Int64)
# getfield(Tuple{UInt64}, Int64, Bool)
# getindex(Tuple{UInt64}, Int64)
# getfield(Tuple{UInt64}, Int64, Bool)
# !=(UInt64, UInt64)
# ==(UInt64, UInt64)
# ===(UInt64, UInt64)
# !(Bool,)
# not_int(Bool,)
# !(Bool,)
# not_int(Bool,)
# Base.Broadcast.extrude(Array{Float64,1},)
# tuple(Array{Float64,1},)
# Base.Broadcast.newindexer(Array{Float64,1},)
# Base.Broadcast.broadcast_axes(Array{Float64,1},)
# axes(Array{Float64,1},)
# size(Array{Float64,1},)
# Core.arraysize(Array{Float64,1}, Int64)
# tuple(Int64,)
# map(UnionAll, Tuple{Int64})
# getindex(Tuple{Int64}, Int64)
# getfield(Tuple{Int64}, Int64, Bool)
# Base.OneTo(Int64,)
# tuple(Base.OneTo{Int64},)
# Base.Broadcast.shapeindexer(Tuple{Base.OneTo{Int64}},)
# Base.Broadcast._newindexer(Tuple{Base.OneTo{Int64}},)
# getindex(Tuple{Base.OneTo{Int64}}, Int64)
# getfield(Tuple{Base.OneTo{Int64}}, Int64, Bool)
# Base.tail(Tuple{Base.OneTo{Int64}},)
# Base.argtail(Base.OneTo{Int64},)
# Base.Broadcast._newindexer(Tuple{},)
# tuple(Tuple{}, Tuple{})
# Base.indexed_iterate(Tuple{Tuple{},Tuple{}}, Int64)
# Base.indexed_iterate(Tuple{Tuple{},Tuple{}}, Int64, Int64)
# getfield(Tuple{Tuple{},Tuple{}}, Int64)
# +(Int64, Int64)
# add_int(Int64, Int64)
# tuple(Tuple{}, Int64)
# getfield(Tuple{Tuple{},Int64}, Int64)
# getfield(Tuple{Tuple{},Int64}, Int64)
# Base.indexed_iterate(Tuple{Tuple{},Tuple{}}, Int64, Int64)
# getfield(Tuple{Tuple{},Tuple{}}, Int64)
# +(Int64, Int64)
# add_int(Int64, Int64)
# tuple(Tuple{}, Int64)
# getfield(Tuple{Tuple{},Int64}, Int64)
# length(Base.OneTo{Int64},)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# !=(Int64, Int64)
# ==(Int64, Int64)
# ===(Int64, Int64)
# !(Bool,)
# not_int(Bool,)
# tuple(Bool,)
# tuple(Bool,)
# first(Base.OneTo{Int64},)
# oneunit(DataType,)
# one(DataType,)
# convert(DataType, Int64)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# tuple(Int64,)
# tuple(Int64,)
# tuple(Tuple{Bool}, Tuple{Int64})
# Base.Broadcast.Extruded(Array{Float64,1}, Tuple{Bool}, Tuple{Int64})
# tuple(Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},)
# tuple(Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}, Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}})
# Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Axes,F,Args} where Args<:Tuple where F where Axes(typeof(/), Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}, Nothing)
# tuple(Base.Broadcast
# Excessive output truncated after 524290 bytes.
# .Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},)
# Base.tail(Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Array{Float64,1},Array{Float64,1}}},Float64},)
# Base.argtail(Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Array{Float64,1},Array{Float64,1}}}, Float64)
# Base.Broadcast.preprocess_args(Array{Float64,1}, Tuple{Float64})
# getindex(Tuple{Float64}, Int64)
# getfield(Tuple{Float64}, Int64, Bool)
# Base.Broadcast.preprocess(Array{Float64,1}, Float64)
# Base.Broadcast.broadcast_unalias(Array{Float64,1}, Float64)
# ===(Array{Float64,1}, Float64)
# Base.unalias(Array{Float64,1}, Float64)
# Base.Broadcast.extrude(Float64,)
# tuple(Float64,)
# tuple(Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}}, Float64)
# Base.Broadcast.Broadcasted{Nothing,Axes,F,Args} where Args<:Tuple where F where Axes(typeof(*), Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}, Tuple{Base.OneTo{Int64}})
# eachindex(Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}},)
# axes(Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}},)
# Base.Broadcast._axes(Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}}, Tuple{Base.OneTo{Int64}})
# Base.Broadcast._eachindex(Tuple{Base.OneTo{Int64}},)
# getindex(Tuple{Base.OneTo{Int64}}, Int64)
# getfield(Tuple{Base.OneTo{Int64}}, Int64, Bool)
# Base.SimdLoop.simd_outer_range(Base.OneTo{Int64},)
# Colon()(Int64, Int64)
# Core.apply_type(UnionAll, DataType)
# UnitRange{Int64}(Int64, Int64)
# Core.apply_type(UnionAll, DataType)
# convert(DataType, Int64)
# Base.unitrange_last(Int64, Int64)
# >=(Int64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# -(Int64, Int64)
# sub_int(Int64, Int64)
# oneunit(Int64,)
# one(Int64,)
# one(DataType,)
# convert(DataType, Int64)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# -(Int64, Int64)
# sub_int(Int64, Int64)
# convert(DataType, Int64)
# ifelse(Bool, Int64, Int64)
# convert(DataType, Int64)
# iterate(UnitRange{Int64},)
# isempty(UnitRange{Int64},)
# first(UnitRange{Int64},)
# convert(DataType, Int64)
# last(UnitRange{Int64},)
# convert(DataType, Int64)
# >(Int64, Int64)
# <(Int64, Int64)
# slt_int(Int64, Int64)
# first(UnitRange{Int64},)
# convert(DataType, Int64)
# first(UnitRange{Int64},)
# convert(DataType, Int64)
# tuple(Int64, Int64)
# ===(Tuple{Int64,Int64}, Nothing)
# not_int(Bool,)
# getfield(Tuple{Int64,Int64}, Int64)
# getfield(Tuple{Int64,Int64}, Int64)
# Base.SimdLoop.simd_inner_length(Base.OneTo{Int64}, Int64)
# length(Base.OneTo{Int64},)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# zero(Int64,)
# oftype(Int64, Int64)
# typeof(Int64,)
# convert(DataType, Int64)
# <(Int64, Int64)
# slt_int(Int64, Int64)
# zero(Int64,)
# oftype(Int64, Int64)
# typeof(Int64,)
# convert(DataType, Int64)
# <(Int64, Int64)
# slt_int(Int64, Int64)
# Base.SimdLoop.simd_index(Base.OneTo{Int64}, Int64, Int64)
# firstindex(Base.OneTo{Int64},)
# IndexLinear()
# eachindex(IndexLinear, Base.OneTo{Int64})
# Base.axes1(Base.OneTo{Int64},)
# axes(Base.OneTo{Int64},)
# size(Base.OneTo{Int64},)
# length(Base.OneTo{Int64},)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# tuple(Int64,)
# map(UnionAll, Tuple{Int64})
# getindex(Tuple{Int64}, Int64)
# getfield(Tuple{Int64}, Int64, Bool)
# Base.OneTo(Int64,)
# tuple(Base.OneTo{Int64},)
# getindex(Tuple{Base.OneTo{Int64}}, Int64)
# getfield(Tuple{Base.OneTo{Int64}}, Int64, Bool)
# first(Base.OneTo{Int64},)
# oneunit(DataType,)
# one(DataType,)
# convert(DataType, Int64)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# +(Int64, Int64)
# add_int(Int64, Int64)
# getindex(Base.OneTo{Int64}, Int64)
# >(Int64, Int64)
# <(Int64, Int64)
# slt_int(Int64, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# &(Bool, Bool)
# and_int(Bool, Bool)
# convert(DataType, Int64)
# getindex(Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}}, Int64)
# checkbounds(Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}}, Int64)
# axes(Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}},)
# Base.Broadcast._axes(Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}}, Tuple{Base.OneTo{Int64}})
# tuple(Int64,)
# Base.checkbounds_indices(DataType, Tuple{Base.OneTo{Int64}}, Tuple{Int64})
# getindex(Tuple{Base.OneTo{Int64}}, Int64)
# getfield(Tuple{Base.OneTo{Int64}}, Int64, Bool)
# getindex(Tuple{Int64}, Int64)
# getfield(Tuple{Int64}, Int64, Bool)
# checkindex(DataType, Base.OneTo{Int64}, Int64)
# first(Base.OneTo{Int64},)
# oneunit(DataType,)
# one(DataType,)
# convert(DataType, Int64)
# Int64(Int64,)
# Core.toInt64(Int64,)
# typeassert(Int64, DataType)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# last(Base.OneTo{Int64},)
# convert(DataType, Int64)
# <=(Int64, Int64)
# sle_int(Int64, Int64)
# &(Bool, Bool)
# and_int(Bool, Bool)
# Base.tail(Tuple{Base.OneTo{Int64}},)
# Base.argtail(Base.OneTo{Int64},)
# Base.tail(Tuple{Int64},)
# Base.argtail(Int64,)
# Base.checkbounds_indices(DataType, Tuple{}, Tuple{})
# &(Bool, Bool)
# and_int(Bool, Bool)
# Base.Broadcast._broadcast_getindex(Base.Broadcast.Broadcasted{Nothing,Tuple{Base.OneTo{Int64}},typeof(*),Tuple{Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(/),Tuple{Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}},Base.Broadcast.Extruded{Array{Float64,1},Tuple{Bool},Tuple{Int64}}}},Float64}}, Int64)
# Base.Broadcast._getindex
